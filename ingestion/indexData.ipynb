# %%
from elasticsearch import Elasticsearch
from elasticsearch import helpers

# %%
from dotenv import load_dotenv
import os

load_dotenv()  # reads .env into environment

es = Elasticsearch(
    os.environ["ES_URL"],
    basic_auth=(
        os.environ["ES_USERNAME"],
        os.environ["ES_PASSWORD"]
    ),
    ca_certs=os.environ["ES_CA_CERT"]
)

# %%
from index_mapping import indexMapping

index_name = "all_products"

if es.indices.exists(index=index_name):
    es.indices.delete(index=index_name)

es.indices.create(index=index_name, mappings=indexMapping)
print(f"Created index '{index_name}' with vector mapping")
# Out:
# Created index 'all_products' with vector mapping

# %% [markdown]
# ## Prepare data

# %%
import pandas as pd
df=pd.read_csv("/home/sonu/Desktop/Hybrid_semantic_search/myntra_products_catalog.csv").loc[:9999]

# %%
df.head()
# Out:
#    ProductID                                        ProductName ProductBrand  \
# 0   10017413  DKNY Unisex Black & Grey Printed Medium Trolle...         DKNY
# 1   10016283  EthnoVogue Women Beige & Grey Made to Measure ...   EthnoVogue
# 2   10009781  SPYKAR Women Pink Alexa Super Skinny Fit High-...       SPYKAR
# 3   10015921  Raymond Men Blue Self-Design Single-Breasted B...      Raymond
# 4   10017833  Parx Men Brown & Off-White Slim Fit Printed Ca...         Parx
#
#    Gender  Price (INR)  NumImages  \
# 0  Unisex        11745          7
# 1   Women         5810          7
# 2   Women          899          7
# 3     Men         5599          5
# 4     Men          759          5
#
#                                          Description PrimaryColor
# 0  Black and grey printed medium trolley bag, sec...        Black
# 1  Beige & Grey made to measure kurta with churid...        Beige
# 2  Pink coloured wash 5-pocket high-rise cropped ...         Pink
# 3  Blue self-design bandhgala suitBlue self-desig...         Blue
# 4  Brown and off-white printed casual shirt, has ...        White

# %%
df.isnull().sum()
# Out:
# ProductID         0
# ProductName       0
# ProductBrand      0
# Gender            0
# Price (INR)       0
# NumImages         0
# Description       0
# PrimaryColor    636
# dtype: int64

# %%
df.fillna("None",inplace=True)

# %% [markdown]
# ## Convert to vectors

# %%
from sentence_transformers import SentenceTransformer

# Load https://huggingface.co/sentence-transformers/all-mpnet-base-v2
model = SentenceTransformer("all-mpnet-base-v2")

# %%
descriptions = df["Description"].tolist()

embeddings = model.encode(
    descriptions,
    batch_size=32,     
    show_progress_bar=True,
    convert_to_numpy=True,
    normalize_embeddings=True
)
# Out:
# Batches:   0%|          | 0/313 [00:00<?, ?it/s]

# %%
def generate_actions(df, embeddings, index_name):
    for i, row in df.iterrows():
        yield {
            "_index": index_name,
            "_id": int(row["ProductID"]),
            "_source": {
                "ProductID": int(row["ProductID"]),
                "ProductName": row["ProductName"],
                "ProductBrand": row["ProductBrand"],
                "Gender": row["Gender"],
                "Price (INR)": int(row["Price (INR)"]),
                "NumImages": int(row["NumImages"]),
                "Description": row["Description"],
                "PrimaryColor": row["PrimaryColor"],
                "DescriptionVector": embeddings[i].tolist()
            }
        }

# %%
success, _ = helpers.bulk(
    client=es,
    actions=generate_actions(df, embeddings, "all_products"),
    chunk_size=500,
    request_timeout=120
)

print(f"Indexed {success} documents successfully")
# Out:
# /tmp/ipykernel_745449/566486951.py:1: DeprecationWarning: Passing transport options in the API method is deprecated. Use 'Elasticsearch.options()' instead.
#   success, _ = helpers.bulk(
# Indexed 10000 documents successfully

# %% [markdown]
# ## embeddings is a numoy array
# Its unnecessary memory after indexing has been done, once data is in es python embeddings and short term scratch space can go

# %%
del embeddings
